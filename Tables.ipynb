# %% [markdown]
# <a href="https://colab.research.google.com/github/Wilheim-ops/Wilheim-ops/blob/main/Tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
training = pd.read_csv('Data2018and2017.csv')
training
# Out:
#    Administration Medical_certificate Medical_history  ...  Shuttle_run  MI  Decision
# 0             Yes                 Fit            None  ...           86  90    Passed
# 1             Yes                 Fit            None  ...           90  89    Passed
# 2             Yes                 Fit            None  ...           86  89    Passed
# 3             Yes                 Fit            None  ...           71  83    Failed
# 4             Yes                 Fit            None  ...           80  79    Failed
# 5             Yes                 Fit     U_Treatment  ...           95  45    Failed
# 6             Yes                 Fit            None  ...           78  89    Passed
# 7             Yes             Not_Fit     U_Treatment  ...           50  90    Failed
# 8             Yes                 Fit            None  ...           70  93    Passed
# 9              No                 Fit            None  ...           90  89    Passed
# ...

# %%
testing = pd.read_csv('Data2016.csv')
testing
# Out:
#    Administration Medical_certificate Medical_history  ...  Shuttle_run  MI  Decision
# 0             Yes                 Fit            None  ...           80  80    Passed
# 1             Yes                 Fit            None  ...           89  90    Passed
# 2             Yes                 Fit            None  ...           86  90    Passed
# 3             Yes             Not_Fit            None  ...           80  93    Passed
# 4             Yes                 Fit            None  ...           70  83    Passed
# 5             Yes                 Fit            None  ...           80  75    Passed
# 6             Yes             Not_Fit     U_Treatment  ...           88  70    Failed
# 7             Yes                 Fit            None  ...           80  83    Passed
# 8             Yes                 Fit            None  ...           74  85    Passed
# 9             Yes                 Fit            None  ...           78   0    Failed
# ...

# %%
df1 = pd.read_excel('Data2018and2017.xlsx')
df1
# Out:
#                                      Name Administration  ...  MI Decision
# 0                  Ni Komang Ayu Sukadani            Yes  ...  90   Passed
# 1              Gusti Ngurah Sukma Apriadi            Yes  ...  89   Passed
# 2                            Zesy Gasella            Yes  ...  89   Passed
# 3                 Iqbal Maulana Hendrawan            Yes  ...  83   Failed
# 4                      William Hamrouwali            Yes  ...  79   Failed
# 5                     Gde Bramanta Kusuma            Yes  ...  45   Failed
# 6                          Elvita Rahmani            Yes  ...  89   Passed
# 7                     I Gede Wira Pratama            Yes  ...  90   Failed
# 8             I Putu Dharma Putra Ritzada            Yes  ...  93   Passed
# 9                      Lalu Riyan Hidayat             No  ...  89   Passed
# 10                       Imroatul Hasanah            Yes  ...  75   Failed
# ...

# %%
df2 = pd.read_excel('Data2016.xlsx')
df2
# Out:
#                          Name Administration  ...  MI Decision
# 0   M. Risma Caesar Wirayanti            Yes  ...  80   Passed
# 1                Rian Azzumar            Yes  ...  90   Passed
# 2   Andreas Dewa Aditya Putra            Yes  ...  90   Passed
# 3      Febrianus Setiadi Guru            Yes  ...  93   Passed
# 4    Ni Kadek Nita Wiryandani            Yes  ...  83   Passed
# 5            I Made Pratiaksa            Yes  ...  75   Passed
# 6          Septyan Adi Wibowo            Yes  ...  70   Failed
# 7      Putu Ayu Erna Mahayani            Yes  ...  83   Passed
# 8          I Gede Adhi Irawan            Yes  ...  85   Passed
# 9      Sang Ayu Nyoman Johani            Yes  ...   0   Failed
# 10              Nana Septyana            Yes  ...  89   Passed
# 11   Ni Kadek Dessi Dwi Yanti            Yes  ...  83   Passed
# 12  Pande Komang Harry Sudewa            Yes  ...  90   Passed
# 13          Kadek Nola Andara            Yes  ...  89   Passed
# ...
